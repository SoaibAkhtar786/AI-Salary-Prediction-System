# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("salary_data.csv")

df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (25, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  25 non-null     float64
#  1   Salary           25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        25.000000      25.000000
# mean          5.104000   75030.040000
# std           2.744765   26767.709953
# min           1.100000   37731.000000
# 25%           3.000000   56642.000000
# 50%           4.900000   66029.000000
# 75%           7.100000   98273.000000
# max          10.300000  122391.000000

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["YearsExperience"],df["Salary"])
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.grid(True)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.979861
# Salary                  0.979861  1.000000

# %%
plt.figure(figsize=(8,5))
plt.plot(df["YearsExperience"],df["Salary"],marker="o")
plt.title("Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.grid(True)
plt.show()

# %%
print("EDA Completed Successfully")
# Out:
# EDA Completed Successfully
